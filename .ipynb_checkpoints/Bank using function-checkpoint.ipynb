# %%
def Credit():
    global bank
    global index
    n = int(input("Enter the number of amount you want to credit : "))
    bal = bank['bal'][index]-n
    print("Your current balance is : ",bal)
    bank['bal'][index]=bal
def Debit():
    global bank
    global index
    n = int(input("Enter the number of amount you want to debit : "))
    bal = bank['bal'][index]+n
    print("Your current balance is : ",bal)
    bank['bal'][index]=bal
def Check_balance():
    global bank
    global index
    print("Your current balance is : ", bank['bal'][index])
def Password_change():
    global bank
    global index
    passwrd = getpass("Enter your old password : ")
    if passwrd == paswrd:
        newpass = getpass("Enter your new password : ")
        checkpass = getpass("Enter your new password again : ")
        if newpass == checkpass:
            print("Your password has been changed successfully!!")
            bank['password'][index] = checkpass
        else :
             print("Your password has not been matched")
    else:
         print("Your old password has not been matched")
def Login():
        global bank
        global index
        accno=int(input("Enter your account number : "))
        index=bank['accno'].index(accno)
        if accno in bank['accno']:
            paswrd=input("Enter your password : ")
            if paswrd in bank['password'][index]:
                while True:
                    print("\n1.\tCredit\n2.\tDebit\n3.\tCheck balance\n4.\tPassword change\n5.\tLogout")
                    c = int(input("Enter your choice : "))
                    if c == 1:
                        Credit()
                    elif c == 2:
                    
                        Debit()
                    elif c == 3:
                        Check_balance()
                    elif c == 4:
                        Password_change()
                    elif c == 5:
                        print("You have been logout!!")
                        break
                    else :
                        print("Invalid Choice!")
            else :
                print("Invalid password")
        else :
            print("Invalid account number")
def Signup():
    global bank
    username = input("\nEnter your username : ")
    passwrd = input("\nEnter your password : ")
    bal = input("\nEnter your balance : ")
    accno = bank ['accno'][-1] + 1
    print("\nYour account number is : ", accno)
    bank['user'].append(username)
    bank['accno'].append(accno)
    bank['password'].append(passwrd)
    bank['bal'].append(bal)
    
def Admin():
        username = input("\nEnter your name: ")
        if username == admin:
            password = getpass("\nPassword: ")
            if password == admin_pass:
                for key,value in bank.items():
                    print()
                    print("{} = {}".format(key,value))
                    print()
            else:
                print("\nCheck your password! \n Try again!")
        else:
            print("\nCheck your username and Try again!")
        
bank = {
       'user' : ['Simran' , 'Rahul' , 'Ravi' ],
        'accno' : [1001 , 1002 , 1003],
        'password' : ['1234' , '5678' , '9876'],
        'bal' : [1000.45 , 5000.00 , 5432.65] }
from getpass import getpass
admin="root"
admin_pass = "root@123"
while True:
    print("*"*50)
    print("WELCOME")
    print("*"*50)
    print("\n\n")
    print("1.\tLogin\n2.\tSignup\n3.\tAdimn\n4.\tExit")
    ch=int(input("\nEnter your choice: "))
    if ch == 1:
        Login()
    elif ch == 2:
        Signup()
    elif ch == 3:
        Admin()
    elif ch == 4:
        choice = input("\nDo you want to continue the exit (y/n) : ").strip().lower()
        if choice == 'y' or choice == 'yes':
            break
        else:
            continue
            
    else :
        print("Invalid Choice!! Try again.")
# Out:
# **************************************************
# WELCOME
# **************************************************
#
#
#
# 1.	Login
# 2.	Signup
# 3.	Adimn
# 4.	Exit
#
# Enter your choice: 1
# Enter your account number : 1002
# Enter your password : 5678
#
# 1.	Credit
# 2.	Debit
# 3.	Check balance
# 4.	Password change
# 5.	Logout
# Enter your choice : 1
# Enter the number of amount you want to credit : 50000
# Your current balance is :  -45000.0
#
# 1.	Credit
# 2.	Debit
# 3.	Check balance
# 4.	Password change
# 5.	Logout
# Enter your choice : 5
# You have been logout!!
# **************************************************
# WELCOME
# **************************************************
#
#
#
# 1.	Login
# 2.	Signup
# 3.	Adimn
# 4.	Exit
#
# Enter your choice: 2
#
# Enter your username : simran
#
# Enter your password : 5678
#
# Enter your balance : 100000
#
# Your account number is :  1004
# **************************************************
# WELCOME
# **************************************************
#
#
#
# 1.	Login
# 2.	Signup
# 3.	Adimn
# 4.	Exit
#
# Enter your choice: 3
#
# Enter your name: root
#
# Password: ········
#
# user = ['Simran', 'Rahul', 'Ravi', 'simran']
#
#
# accno = [1001, 1002, 1003, 1004]
#
#
# password = ['1234', '5678', '9876', '5678']
#
#
# bal = [1000.45, -45000.0, 5432.65, '100000']
#
# **************************************************
# WELCOME
# **************************************************
#
#
#
# 1.	Login
# 2.	Signup
# 3.	Adimn
# 4.	Exit
#
# Enter your choice: 4
#
# Do you want to continue the exit (y/n) : y
